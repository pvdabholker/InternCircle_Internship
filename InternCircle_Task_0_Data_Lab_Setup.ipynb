# %% [markdown]
# <a href="https://colab.research.google.com/github/pvdabholker/InternCircle_Internship/blob/main/InternCircle_Task_0_Data_Lab_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # InternCircle Data Science & AI Internship
#
# ## Task 1: Data Lab Setup
#
# This notebook contains the setup and basic testing of a Python-based
# Data Science environment using Google Colab.
#
# ### Objective
#
# To configure and test the environment required for data analysis
# and visualization.
#
# ### Tools and Libraries
#
# - Python
# - Google Colab
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Data Science Lab Setup Completed Successfully!")
# Out:
# Data Science Lab Setup Completed Successfully!

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns

print("Python Version:")
print(sys.version)

print("\nPandas Version:")
print(pd.__version__)

print("\nNumPy Version:")
print(np.__version__)

print("\nMatplotlib Version:")
print(matplotlib.__version__)

print("\nSeaborn Version:")
print(sns.__version__)
# Out:
# Python Version:
# 3.13.15 (main, Aug  6 2026, 11:06:22) [GCC 13.3.0]
#
# Pandas Version:
# 2.2.3
#
# NumPy Version:
# 2.1.3
#
# Matplotlib Version:
# 3.10.0
#
# Seaborn Version:
# 0.13.2

# %%
data = {
    "Student": ["A", "B", "C", "D", "E"],
    "Marks": [78, 85, 92, 67, 88]
}

df = pd.DataFrame(data)

print("Sample Dataset:")
display(df)
# Out:
# Sample Dataset:
#   Student  Marks
# 0       A     78
# 1       B     85
# 2       C     92
# 3       D     67
# 4       E     88

# %%
print("Basic Statistical Summary:")
display(df.describe())
# Out:
# Basic Statistical Summary:
#            Marks
# count   5.000000
# mean   82.000000
# std     9.823441
# min    67.000000
# 25%    78.000000
# 50%    85.000000
# 75%    88.000000
# max    92.000000

# %%
plt.figure(figsize=(8, 5))

sns.barplot(x="Student", y="Marks", data=df)

plt.title("Student Marks")
plt.xlabel("Student")
plt.ylabel("Marks")

plt.show()

# %% [markdown]
# ## Conclusion
#
# The Google Colab Data Science environment was successfully configured
# and tested. Python, Pandas, NumPy, Matplotlib and Seaborn were imported
# and verified. A sample dataset was created and basic data analysis and
# visualization were performed successfully.
